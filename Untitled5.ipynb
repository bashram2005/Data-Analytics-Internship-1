# %%
city = str(input("What city do you live in"))
temperature = float(input("What temperature is it?"))
is_raining = input("Is it raining?")


print(city)
print(temperature)
if is_raining == True:
    print("raining")
else:
    print("not raining")
# Out:
# What city do you live in ny
# What temperature is it? 60
# Is it raining? yes
# ny
# 60.0
# not raining

# %%
city = input("What city do you live in?")
temperature = float(input("What's the temperature?"))
is_raining = input("Is it raining? (Y/N)")

print("In", city, "it is", temperature, "and")
if is_raining == "Y":
    print("raining.")
else:
    print("not raining.")
# Out:
# What city do you live in? New York
# What's the temperature? 60
# Is it raining? (Y/N) Y
# In New York it is 60.0 and
# raining.

# %%
age = int(input("how old are you?"))

print("you will be", (age + 5), "in five years")
# Out:
# how old are you? 5
# you will be 10 in five years

# %%
age_in_5_years = int(input("how old are you?")) + 5

print("you will be", age_in_5_years, "in 5 years")
# Out:
# how old are you? 8
# you will be 13 in 5 years

# %%
name = input("What's your name")
age = int(input("How old are you"))

print("Hello,", name + ", next year you will be", age + 1)
# Out:
# What's your name Seb
# How old are you 21
# Hello, Seb, next year you will be 22

# %%
number = int(input("send a number"))

print(number, "+ 5 =", number + 5)
print(number, "* 2 =", number * 2)
print(number, "- 3 =", number - 3)
# Out:
# send a number 10
# 10 + 5 = 15
# 10 * 2 = 20
# 10 - 3 = 7

# %%
number = int(input("send a number"))

number_plus_5 = number + 5
number_times_2 = number * 2
number_minus_3 = number - 3

print(number, "+ 5 =", number_plus_5)
print(number, "* 2 =", number_times_2)
print(number, "- 3 =", number_minus_3)
# Out:
# send a number 10
# 10 + 5 = 15
# 10 * 2 = 20
# 10 - 3 = 7

# %%
age = 25
height = 5.9
name = "Alex"
is_student = True

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
