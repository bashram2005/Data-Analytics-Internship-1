# %%
number = int(input("give me a number"))
for i in range(1, number + 1):
    print(i*i)

# %%
number = int(input("give me a number"))
for i in range(1, 11):
    print(number * i)

# %%
number = int(input("give me a number"))
if number < 10:
    print("small")
else:
    print("big")

# %%
number = int(input("give me a number"))
if number % 2 == 0:
    print("even")
else: print("odd")

# %%
number = int(input("give me a number"))
if number == 0: 
    print("zero")
elif number > 0:
    print("positive")
else: 
    print("negative")

# %%
number = int(input("give me a number"))
if number % 3 == 0:
    print("divisible by 3")
else:
    print("not divisible by 3")

# %%
for i in range(1,11):
    print(i)

# %%
user_input = input("Enter something: ")
print("You entered: ", user_input)

# %%
i = 1
while i <= 10: 
    print(i + i)

# %%
number = int(input("give me a number"))
for i in range(1, number + 1):
    if i % 2 == 0:
        even_count = even_count + i
        print(even_count)

# %%
# to prompt user to pick between naruto, john batiste or michael jackson
user_chooses = input("Who would you like to talk to? Mario? Jon Batiste? Michael Jackson?")

# to set variables for user_chooses
mario = "Mario" or "mario"
jon_batiste = "jon batiste" or "Jon Batiste" or "jon" or "Jon" or "JON" or "JON BATISTE"
mj = "Michael Jackson" or "MJ" or "mj" or "Mike" or "mike" or "michael" or "Michael"

if user_chooses == mario:
    print("Hey, itsa me! Mario! How we doing?")

elif user_chooses == jon_batiste:
    print("Hey I'm Jon Batiste. You gotta know there to go there. What's up?")

elif user_chooses == mj:
    print("Hee hee! Hey it's me, the king of pop. Ow! Hee hee!")
# Out:
# Who would you like to talk to? Mario? Jon Batiste? Michael Jackson? mario

# %%
user_chooses = input("Who would you like to talk to? Mario? Jon Batiste? Michael Jackson?")

mario = user_chooses == "Mario" or "mario"

if user_chooses == mario:
    print("itsa me mario")
else:
    print("They're actually unavailable right now. Sorry :(")

yes_no = input("Can I help you with anything else? (Y/N)")

yes = yes_no == "Y" 
no = yes_no == "N"

if yes_no == no:
    print("Awesome, bye.")
else:
    print("Okay, don't care. Bye now!")
# Out:
# Who would you like to talk to? Mario? Jon Batiste? Michael Jackson? mario
# itsa me mario
# Can I help you with anything else? (Y/N) N
# Okay, don't care. Bye now!

# %%
# Notes
high_income = True
good_credit = True

if high_income and good_credit:
    print(eligible"
# Out:
# eligible

# %%
test_score = int(input("tell me your test score buddy"))
# don't need to write upper limits (eg. test_score < 90) because earlier conditions already filtered them

if test_score > 100:
    print("A, +", test_score-100, "extra-credit")
elif test_score == 0:
    print("F| wow, there's no way. couldn't you have guessed right at least once?")
elif test_score == 100:
    print("A| wow! perfect score... well done")
elif test_score >= 90:
    print("A| good job!")
elif test_score >= 80:
    print("B| pretty good, but i know you can do better!")
elif test_score >= 70:
    print("C| better luck next time!")
elif test_score >= 60:
    print("D| did you study?")
elif test_score > 0:
    print("F| c'mon man")
else:
    print("hope this was a typo. is it possible to get a negative score?")
# Out:
# tell me your test score buddy 12
# F| c'mon man
