# %%
print(10/4)
# Out:
# 2.5

# %%
firstvariable=10/4
print(firstvariable)
# Out:
# 2.5

# %%
firstvariable=int(10/3)
print(firstvariable)
# Out:
# 3

# %%
firstvariable=10%3
again=3*4
print(again)
# Out:
# 12

# %%
print(firstvariable)
# Out:
# 1

# %%
type(firstvariable)
# Out:
# int

# %%
withdrawal_amount=845
dollars_100=X1
dollars_50=X2
dollars_20=X3
dollars_10=X4
dollars_1=X5
print('here is ', str(X1)+ ' of 100 dollars'+str(X2)+ ' of 50 dollars'+str(X3)+ ' of 10 dollars'+str(X4)+ ' of 1 dollars' )
# Out:
# here is 4 of 100 dollars1 of 50 dollars1 of 10 dollars3 of 1 dollars

# %%
withdrawal_amount=845
print('here is:')
dollars_100 = int(withdrawal_amount/100)
print(dollars_100,'of 100 dollar bills')
remainder_100 = withdrawal_amount%100

dollars_50 = int(remainder_100/50)
print(dollars_50, 'of 50 dollar bills')
remainder_50 = remainder_100%50

dollars_20 = int(remainder_50/20) 
print(dollars_20, 'of 20 dollar bills')
remainder_20 = remainder_50%20

dollars_10 = int(remainder_20/10)
print(dollars_10, 'of 10 dollar bills')
remainder_10 = remainder_20%10

dollars_1 = int(remainder_10/1)
print(dollars_1, 'of 1 dollar bills')
# Out:
# here is:
# 8 of 100 dollar bills
# 0 of 50 dollar bills
# 2 of 20 dollar bills
# 0 of 10 dollar bills
# 5 of 1 dollar bills

# %%
withdrawal_amount=845
print('here is:')
dollar_bill = int(withdrawal_amount/100)
print(dollar_bill,'of 100 dollar bills')
remainder = withdrawal_amount%100

dollar_bill = int(remainder/50)
print(dollar_bill, 'of 50 dollar bills')
remainder = remainder%50

dollar_bill = int(remainder/20) 
print(dollar_bill, 'of 20 dollar bills')
remainder = remainder%20

dollar_bill = int(remainder/10)
print(dollar_bill, 'of 10 dollar bills')
remainder = remainder%10

dollar_bill = int(remainder/1)
print(dollar_bill, 'of 1 dollar bills')
# Out:
# here is:
# 8 of 100 dollar bills
# 0 of 50 dollar bills
# 2 of 20 dollar bills
# 0 of 10 dollar bills
# 5 of 1 dollar bills

# %%
withdrawal_amount=845

outcome = 'here is:'
dollar_bill = int(withdrawal_amount/100)
outcome = outcome, dollar_bill, 'of 100 dollar bills,'
remainder = withdrawal_amount%100


dollar_bill = int(remainder/50)
outcome = outcome, dollar_bill, str('of 50 dollar bills,')
remainder = remainder%50

dollar_bill = int(remainder/20) 
outcome = outcome, dollar_bill, str('of 20 dollar bills,')
remainder = remainder%20

dollar_bill = int(remainder/10)
outcome = outcome, dollar_bill, str('of 10 dollar bills,')
remainder = remainder%10

dollar_bill = int(remainder/1)
outcome = outcome, str('and'), str(dollar_bill), str('of 1 dollar bills.')
print(outcome)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 5
#       3 outcome = 'here is:'
#       4 dollar_bill = int(withdrawal_amount/100)
# ----> 5 outcome = str(outcome, dollar_bill, 'of 100 dollar bills,')
#       6 remainder = withdrawal_amount%100
#       9 dollar_bill = int(remainder/50)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
withdrawal_amount=845

outcome = 'here is:'
dollar_bill = int(withdrawal_amount/100)
outcome = (outcome + ' ' + str(dollar_bill)+ " of 100 dollar bills,")
remainder = withdrawal_amount%100

dollar_bill = int(remainder/50)
outcome = (outcome + ' ' + str(dollar_bill)+ " of 50 dollar bills,")
remainder = remainder%50

dollar_bill = int(remainder/20) 
outcome = (outcome + ' ' + str(dollar_bill)+ " of 20 dollar bills,")
remainder = remainder%20

dollar_bill = int(remainder/10)
outcome = (outcome + ' ' + str(dollar_bill)+ " of 10 dollar bills, and")
remainder = remainder%10

dollar_bill = int(remainder/1)
outcome = (outcome + ' ' + str(dollar_bill)+ " of 1 dollar bills.")

print(outcome)
# Out:
# here is: 8 of 100 dollar bills, 0 of 50 dollar bills, 2 of 20 dollar bills, 0 of 10 dollar bills, and 5 of 1 dollar bills.
