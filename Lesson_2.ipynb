# %%
message1 = 'hello' + ' ' + 'world'
print(message1)
# Out:
# hello world

# %%
message2a = 'hello ' * 3
message2b = 'world'
print(message2a + message2b)
# Out:
# hello hello hello world

# %%
message3 = 'howdy' 
message3 += '4 ' 

# message3 += '4 ' == message3 = message3 + ' 4 '

message3 = message3 + ' 4 '
message3 += 'world' 
print(message3)
# Out:
# howdy4  4 world

# %%
message4 = 'hello' + ' ' + 'world'
print(len(message4))
# len == length (will print amount of characters in a string)
# Out:
# 11

# %%
message5 = "hello world"
message5a = message5.find("worl")
print(message5a)
# if doesn't exist, will print -1
# Out:
# 6

# %%
message7 = "HELLO WORLD"
message7a = message7.lower()
print(message7a)
# Out:
# hello world

# %%
message8 = "HELLO WORLD"
message8a = message8.replace("L", "pizza")
print(message8a)
# Out:
# HEpizzapizzaO WORpizzaD

# %%
message9 = "Hello World"
message9a = message9[3:9]
print(message9a)
# Out:
# lo Wor

# %%
startLoc = 2
endLoc = 8
message9b = message9[startLoc: endLoc]
print(message9b)
# Out:
# llo Wo

# %%
message9 = "Hello World"
print(message9[:5].find("d"))
# Out:
# -1

# %%
print(len(message7))
# Out:
# 11

# %%
number = int(input('Enter a number: '))

# check if number is greater than 0
if number > 0:
    print('{number} is a positive number.')
    print('I am an if condition')
print(f'I am always out of if condition')

# f will only work if there's a variable, without f, variable will print as it's text, rather than it's assigned meaning
print('A statement outside the if statement.')
# Out:
# Enter a number:  6
# {number} is a positive number.
# I am an if condition
# I am always out of if condition
# A statement outside the if statement.

# %%
x = 1
total = 0 

# start of the if statement 
if x != 0:
    total += x
    print(total)
# end of the if statement

print("This is always excecuted.")
# Out:
# 1
# This is always excecuted.

# %%
number = int(input('Enter a number: '))

if number > 0:
    print('Positive number')
    print('Condition true')
else:
    print('Negative number')
    print('Condition false')

print('This statment always excecutes')
# Out:
# Enter a number:  3
# Positive number
# Condition true
# This statment always excecutes

# %%
number = -5

if number > 0:
    print('Positive number')

elif number > 0:
    print('Negative number')

else:
    print('Zero')

print('This statement is always executed')
# Out:
# Zero
# This statement is always executed

# %%
number = 5

# outer if statement
if number >= 0:
    # innner if statement
    if number == 0:
        print('Number is 0')

    # inner else statement
    else: 
        print('Number is positive')

# outer else statement
else:
    print('Number is negative')
# Out:
# Number is positive

# %%
mystring = "abc"
for x_char in mystring:
    print('hello')
    print('world')
    print(x_char)
# Out:
# hello
# world
# a
# hello
# world
# b
# hello
# world
# c

# %%
s = "abc"
for x in s:
    print(x)
# Out:
# a
# b
# c

# %%
for index in range(9):
    print(index)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for index in range(len(mystring)):
    # print(index)
    print(mystring[index])
# Out:
# a
# b
# c

# %%
cnt = 0 
while (cnt < 3):
    cnt = cnt + 1
    print("Hello Geek")
print(cnt)
# Out:
# Hello Geek
# Hello Geek
# Hello Geek
# 3

# %%
cnt = 0 
while (cnt < 3):
    cnt = cnt + 1
    print("Hello Geek")
    print(f"cnt valu={cnt} ")
print(f"we are out of loop {cnt}")
# Out:
# Hello Geek
# cnt valu=1
# Hello Geek
# cnt valu=2
# Hello Geek
# cnt valu=3
# we are out of loop 3

# %%
cnt = 0 
cond=cnt < 3
print(cond)
print(type(cond))
while (cnt < 3):
    cnt = cnt + 1
    print("Hello Geek")
    print(f"cnt valu={cnt} ")
print(f"we are out of loop {cnt}")
# Out:
# True
# <class 'bool'>
# Hello Geek
# cnt valu=1
# Hello Geek
# cnt valu=2
# Hello Geek
# cnt valu=3
# we are out of loop 3

# %%
cnt = 0 
cond=cnt < 3
print(cond)
print(type(cond))
while (cnt < 3):
# if while True: [will create infinite loop]
    cnt = cnt + 1
    print("Hello Geek")
    print(f"cnt valu={cnt} ")
print(f"we are out of loop {cnt}")

# %%
for letter in 'geeksforgeeks':
    if letter == 'e' or letter == 's':
        break

print('Current Letter :', letter)
# Out:
# Current Letter : e

# %%
user_input = input("Give me a
