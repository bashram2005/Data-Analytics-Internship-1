# %%
user_input = 'madam'

end_of_string = len(user_input)

if user_input[0] == user_input[end_of_string-1]:
    print('true')
else:
    print('false')
# Out:
# true

# %%
print(user_input[0])
# Out:
# t

# %%
user_input = 'pizza bagel'

end_of_string = len(user_input)

print(end_of_string)
# Out:
# 11

# %%
user_input = 'madam'
index = 0 
end_index = len(user_input)-1

while index < len(user_input) < end_index:
    print(user_input[index])
    # index = index + 1
    index += 1
    index -= 1

# %%
user_input = 'madam'
index = 0
end_index = len(user_input) - 1

is_palindrome = True

while index < end_index:
    print('im in the while')
    if user_input[index] == user_input[end_index]:
        print('im in the if')
        index += 1
        end_index -= 1
    
    else:
        is_palindrome == False
        break
print(is_palindrome)
# Out:
# im in the while
# im in the if
# im in the while
# im in the if
# True

# %%
print('cheese')
# Out:
# cheese

# %%
print(len(user_input )-1)
# Out:
# 4

# %%
user_input = 'madam'
index = 0
end_index = len(user_input) -1

if user_input[index] == user_input[end_index]:
    print('true')
# Out:
# 5
# true

# %%
user_input = 'madam'
index = 0 
while index < len(user_input):
    
    print(user_input[index])
    index += 1
# Out:
# m
# a
# d
# a
# m
