# %% [markdown]
# ###### number = int(input("i am the decider of even-ness and oddness... test me if you dare"))
#
# if number % 2 == 0:
#     print("even")
# else:
#     print("odd")

# %%
number = int(input("i am the decider of even-ness and oddness... test me if you dare"))

if number % 2 == 0:
    print("EVEN")
else:
    print("ODD")
# Out:
# i am the decider of even-ness and oddness... test me if you dare en
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 number = int(input("i am the decider of even-ness and oddness... test me if you dare"))
#       3 if number % 2 == 0:
#       4     print("EVEN")
#
# ValueError: invalid literal for int() with base 10: 'en'

# %%
while True: 
    user_input = (input("i am the decider of even-ness and oddness... test me if you dare"))
    if user_input == "STOP"
        break
        if: number % 2 == 0:
            print("EVEN")
        else:
            print("ODD")
    input("is that all you got? say STOP if you're done")
# Out:
#   Cell In[21], line 2
#     user_input =:
#                 ^
# SyntaxError: invalid syntax
